# %%
# Import modules for working with excel sheets and for plotting

# matplotlib: module for plotting
# pandas: module for working with dataframe (can be imported from excel, csv, txt)
# %: ipython magic, to plot graphs in line
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import re
from scipy import stats
# %matplotlib inline

# %%
ca_data = pd.ExcelFile('../assets/to_combine/CTRL_L89A.xlsx')
data=combine_ca_data = ca_data.parse("Sheet1")
ax = sns.lineplot(x="Time (s)", y="F/Fo", hue="Genotype", ci=95, data=combine_ca_data).set_title('3 uM UTP, Ca2+ free')
plt.xlim(0, 150)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0d44928f21f6> in <module>()
#       3 ax = sns.lineplot(x="Time (s)", y="F/Fo", hue="Genotype", ci=95, data=combine_ca_data).set_title('3 uM UTP, Ca2+ free')
#       4 plt.xlim(0, 150)
# ----> 5 plt.fill_between(x="Time (s)", y="F/Fo",where=(x>40) & (x<=120),color='b')
#       6 plt.show()
#
# NameError: name 'x' is not defined

# %%
type(combine_ca_data)
# Out:
# pandas.core.frame.DataFrame

# %%
combine_ca_data.head()
# Out:
#    Time (s) Genotype  Coverslip  Cell number      F/Fo
# 0      0.00     CTRL          1            1  1.035578
# 1      0.25     CTRL          1            1  1.015798
# 2      0.50     CTRL          1            1  1.033718
# 3      0.75     CTRL          1            1  1.002494
# 4      1.00     CTRL          1            1  1.031355

# %%
CTRL = combine_ca_data[combine_ca_data['Genotype'].str.contains("CTRL")]
ax = sns.lineplot(x="Time (s)", y="F/Fo", hue="Coverslip", ci=95, data=combine_ca_data).set_title('3 uM UTP, Ca2+ free')
plt.xlim(0, 150)
plt.show()

# %%
list(CTRL)
# Out:
# ['Time (s)', 'Genotype', 'Coverslip', 'Cell number', 'F/Fo']
